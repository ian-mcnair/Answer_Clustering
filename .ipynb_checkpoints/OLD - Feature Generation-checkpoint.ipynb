# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
set(stopwords.words('english'))

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_lg")

# %%
from sklearn.cluster import KMeans
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/patilpranjal/Auto-Grader-for-short-answer-Question-using-Siamese-Neural-Network/master/Dataset.csv"
df = pd.read_csv(
    url,
    index_col= 0
)

# %% [markdown]
# # Basic Dataset Description

# %%
df.head()
# Out:
#                                        studentAnswer  \
# 0             By letting it sit in a dish for a day.
# 1  Let the water evaporate and the salt is left b...
# 2       The water evaporated and left salt crystals.
# 3  I saw a pinkish grayish color that was blockin...
# 4  You have to slowly tip the vial for only the w...
#
#                                referenceAnswer  \
# 0  The water was evaporated, leaving the salt.
# 1  The water was evaporated, leaving the salt.
# 2  The water was evaporated, leaving the salt.
# 3  The water was evaporated, leaving the salt.
# 4  The water was evaporated, leaving the salt.
#
#                                                ref_1  \
# 0  We evaporated the salt from the water because ...
# 1  We evaporated the salt from the water because ...
# 2  We evaporated the salt from the water because ...
# 3  We evaporated the salt from the water because ...
# 4  We evaporated the salt from the water because ...
#
#                                                ref_2   accuracy
# 0  I put some water in a dish and let the water e...  incorrect
# 1  I put some water in a dish and let the water e...    correct
# 2  I put some water in a dish and let the water e...    correct
# 3  I put some water in a dish and let the water e...  incorrect
# 4  I put some water in a dish and let the water e...  incorrect

# %%
df.referenceAnswer.value_counts().size
# 135 Unique Questions
# Out:
# 135

# %%
df.referenceAnswer.value_counts().mean()
# 36.5 student responses
# Out:
# 36.48148148148148

# %%
df["accuracy"] = df.accuracy.apply(lambda x: 1 if x == "correct" else 0)
df.head(20)
# Out:
#                                         studentAnswer  \
# 0              By letting it sit in a dish for a day.
# 1   Let the water evaporate and the salt is left b...
# 2        The water evaporated and left salt crystals.
# 3   I saw a pinkish grayish color that was blockin...
# 4   You have to slowly tip the vial for only the w...
# 5   By pouring the water and salt into the thing, ...
# 6                     By slowly pouring it in a tray.
# 7   The water evaporated so there was only salt left.
# 8   We put the water with the salt in it and put i...
# 9   I separated the salt from the water because th...
# 10                 Because you can see salt in water.
# 11                         I let the water evaporate.
# 12              The water dried up and left the salt.
# 13                        We let the water evaporate.
# 14                                The water dried up.
# 15  You just get water and the smashed mock rock a...
# 16  You put the water, a little bit, in a cup and ...
# 17  We evaporated the salt from the water because ...
# 18  We put the water and salt in the Petri dish. T...
# 19  We poured the salt into a Petri dish and poure...
#
#                                 referenceAnswer  \
# 0   The water was evaporated, leaving the salt.
# 1   The water was evaporated, leaving the salt.
# 2   The water was evaporated, leaving the salt.
# 3   The water was evaporated, leaving the salt.
# 4   The water was evaporated, leaving the salt.
# 5   The water was evaporated, leaving the salt.
# 6   The water was evaporated, leaving the salt.
# 7   The water was evaporated, leaving the salt.
# 8   The water was evaporated, leaving the salt.
# 9   The water was evaporated, leaving the salt.
# 10  The water was evaporated, leaving the salt.
# 11  The water was evaporated, leaving the salt.
# 12  The water was evaporated, leaving the salt.
# 13  The water was evaporated, leaving the salt.
# 14  The water was evaporated, leaving the salt.
# 15  The water was evaporated, leaving the salt.
# 16  The water was evaporated, leaving the salt.
# 17  The water was evaporated, leaving the salt.
# 18  The water was evaporated, leaving the salt.
# 19  The water was evaporated, leaving the salt.
#
#                                                 ref_1  \
# 0   We evaporated the salt from the water because ...
# 1   We evaporated the salt from the water because ...
# 2   We evaporated the salt from the water because ...
# 3   We evaporated the salt from the water because ...
# 4   We evaporated the salt from the water because ...
# 5   We evaporated the salt from the water because ...
# 6   We evaporated the salt from the water because ...
# 7   We evaporated the salt from the water because ...
# 8   We evaporated the salt from the water because ...
# 9   We evaporated the salt from the water because ...
# 10  We evaporated the salt from the water because ...
# 11  We evaporated the salt from the water because ...
# 12  We evaporated the salt from the water because ...
# 13  We evaporated the salt from the water because ...
# 14  We evaporated the salt from the water because ...
# 15  We evaporated the salt from the water because ...
# 16  We evaporated the salt from the water because ...
# 17  We evaporated the salt from the water because ...
# 18  We evaporated the salt from the water because ...
# 19  We evaporated the salt from the water because ...
#
#                                                 ref_2  accuracy
# 0   I put some water in a dish and let the water e...         0
# 1   I put some water in a dish and let the water e...         1
# 2   I put some water in a dish and let the water e...         1
# 3   I put some water in a dish and let the water e...         0
# 4   I put some water in a dish and let the water e...         0
# 5   I put some water in a dish and let the water e...         1
# 6   I put some water in a dish and let the water e...         0
# 7   I put some water in a dish and let the water e...         1
# 8   I put some water in a dish and let the water e...         1
# 9   I put some water in a dish and let the water e...         0
# 10  I put some water in a dish and let the water e...         0
# 11  I put some water in a dish and let the water e...         1
# 12  I put some water in a dish and let the water e...         1
# 13  I put some water in a dish and let the water e...         1
# 14  I put some water in a dish and let the water e...         1
# 15  I put some water in a dish and let the water e...         0
# 16  I put some water in a dish and let the water e...         0
# 17  I put some water in a dish and let the water e...         1
# 18  I put some water in a dish and let the water e...         1
# 19  I put some water in a dish and let the water e...         0

# %% [markdown]
# # Removing Stop Words

# %%
answer = "The water was evaporated, leaving the salt."
token_list = []
for token in :
    token_list.append(token.text)

# %%
my_doc = nlp(answer)

# %%
from spacy.lang.en.stop_words import STOP_WORDS

# %%
filtered_sentence =[] 

for word in token_list:
    lexeme = nlp.vocab[word]
    if lexeme.is_stop == False:
        filtered_sentence.append(word) 
print(token_list)
print(filtered_sentence)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-729061e3f183> in <module>
#       2
#       3 for word in token_list:
# ----> 4     lexeme = nlp.vocab[word]
#       5     if lexeme.is_stop == False:
#       6         filtered_sentence.append(word)
#
# vocab.pyx in spacy.vocab.Vocab.__getitem__()
#
# TypeError: an integer is required
